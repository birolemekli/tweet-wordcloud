# %%
# -*- coding: utf-8 -*-

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

import pandas as pd

import imageio


'''data = pd.read_excel('./veri.xlsx')

pozitif=data[data['tags']=="pozitif"]
negatif=data[data['tags']=="negatif"]

#pozitif=pozitif.tweet.str.split()
#negatif=negatif.tweet.str.split()

with open('negatif.txt','w') as f:
    f.write(negatif['tweet'].to_string(header = False, index = False))

with open('pozitif.txt','w') as f:
    f.write(pozitif['tweet'].to_string(header = False, index = False))'''


'''
twitter_mask = imageio.imread('./twitter_mask.png')

wordcloud = WordCloud(
                      stopwords=STOPWORDS,
                      background_color='white',
                      width=2000,
                      height=1400,
                      margin=0,
                      mask=twitter_mask
            ).generate(str(pozitif))


fig = plt.figure( figsize = (14, 11))

plt.imshow(wordcloud)
plt.axis("off")
plt.savefig('./my_twitter_wordcloud_2.png', dpi=300)
plt.show()
'''


import stylecloud

#stylecloud.gen_stylecloud(file_path = "olumsuz-word-cloud", colors=['#ecf0f1', '#3498db', '#e74c3c'],icon_name= "fab fa-twitter",
#                          palette="cartocolors.diverging.TealRose_3", background_color="black")

# %%
import pandas as pd 
import stylecloud
from nltk.corpus import stopwords

# %%
data = pd.read_excel('../tumkarisik.xlsx')

# %%
data
# Out:
#                                                   tweet     tags
# 0     huawei cihazlarda gündür genel internet sorunu...  negatif
# 1     emir orta yerinde çekmiyor birde sorununuza çö...  negatif
# 2     sizin beş para etmez hizmet kaliteniz süperbox...  negatif
# 3     turkcell geçtiğim günden beri turkcell lanet e...  negatif
# 4     yıla yakındır turkcell kullanıyordum ama bende...  negatif
# ...                                                 ...      ...
# 1722  türk telekoma git vodafone pişmanlık oluyor so...  negatif
# 1723  hem vodafone dan pişmanım hem turknetten ikisi...  negatif
# 1724  maf ettin milleti vodafone internet bağlantısı...  negatif
# 1725  gündür internete bağlamak için bekleten vodafo...  negatif
# 1726    lanet olası vodafone yüzde elli düşürdü sanırım  negatif
#
# [1727 rows x 2 columns]
